# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import zipfile

zip_file_path = "API_SP.POP.TOTL_DS2_en_csv_v2_900.zip"
csv_file_name = "API_SP.POP.TOTL_DS2_en_csv_v2_900.csv"

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    try:
        df = pd.read_csv(zip_ref.open(csv_file_name), sep=';', header=0)  # Try semicolon
    except pd.errors.ParserError:
        df = pd.read_csv(zip_ref.open(csv_file_name), sep='\t', header=0)  # Try tab
    except pd.errors.ParserError:

        print("Error: Could not determine the correct delimiter. Check the CSV file format.")

print(df.head())
# Out:
#          Data Source,"World Development Indicators",
# 0                    Last Updated Date,"2024-12-16",
# 1  Country Name,"Country Code","Indicator Name","...
# 2  Aruba,"ABW","Population, total","SP.POP.TOTL",...
# 3  Africa Eastern and Southern,"AFE","Population,...
# 4  Afghanistan,"AFG","Population, total","SP.POP....

# %%
df
# Out:
#            Data Source,"World Development Indicators",
# 0                      Last Updated Date,"2024-12-16",
# 1    Country Name,"Country Code","Indicator Name","...
# 2    Aruba,"ABW","Population, total","SP.POP.TOTL",...
# 3    Africa Eastern and Southern,"AFE","Population,...
# 4    Afghanistan,"AFG","Population, total","SP.POP....
# ..                                                 ...
# 263  Kosovo,"XKX","Population, total","SP.POP.TOTL"...
# 264  Yemen, Rep.,"YEM","Population, total","SP.POP....
# 265  South Africa,"ZAF","Population, total","SP.POP...
# 266  Zambia,"ZMB","Population, total","SP.POP.TOTL"...
# 267  Zimbabwe,"ZWE","Population, total","SP.POP.TOT...
#
# [268 rows x 1 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate value counts and select the top 5 categories
data_source_counts = df['Data Source,"World Development Indicators",'].value_counts().head(5)

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.bar(data_source_counts.index, data_source_counts.values)
plt.xlabel('Data Source, "World Development Indicators"')
plt.ylabel('Count')
plt.title('Distribution of Top 5 Data Sources')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-39-32045b3b1f85>:14: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df.shape
# Out:
# (268, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 1 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Data Source,"World Development Indicators",  268 non-null    object
# dtypes: object(1)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#        Data Source,"World Development Indicators",
# count                                          268
# unique                                         268
# top                Last Updated Date,"2024-12-16",
# freq                                             1

# %%
df.isnull().sum()
# Out:
# Data Source,"World Development Indicators",    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 1 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Data Source,"World Development Indicators",  268 non-null    object
# dtypes: object(1)
# memory usage: 2.2+ KB
